# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from plotnine import ggplot, aes, geom_bar, geom_histogram, coord_flip

# %%
#read data

churn_data = pd.read_excel("C:\\Users\\rayjohndp\\Desktop\\Projects\\DS_Python_Portfolio\\Telecom_Churn_Project\\artifacts\\data_ingestion\\Telecom Churn Rate Dataset.xlsx")

# %%
churn_data['Churn'].value_counts(sort=True)
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
churn_data['Churn']
# Out:
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
# Name: Churn, Length: 7043, dtype: object

# %%
churn_data.Churn.replace(('Yes','No'), (1,0),inplace=True)
# Out:
# C:\Users\rayjohndp\AppData\Local\Temp\ipykernel_31152\1097531162.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`

# %%
churn_data['Churn']
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 7043, dtype: int64

# %%
churn_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... StreamingTV  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...          No
# 4                No     Fiber optic             No  ...          No
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# ...

# %%
churn_data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  numAdminTickets  \
# count    7043.000000  7043.000000     7043.000000      7043.000000
# mean        0.162147    32.371149       64.761692         0.515689
# std         0.368612    24.559481       30.090047         1.275299
# min         0.000000     0.000000       18.250000         0.000000
# 25%         0.000000     9.000000       35.500000         0.000000
# 50%         0.000000    29.000000       70.350000         0.000000
# 75%         0.000000    55.000000       89.850000         0.000000
# max         1.000000    72.000000      118.750000         5.000000
#
#        numTechTickets
# count     7043.000000
# mean         0.419566
# std          1.250117
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          9.000000

# %%
churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
#sns.histplot(x = "gender",hue="Churn",data=churn_data)

#churn_data["gender"].value_counts(sort=True)
(
    ggplot(churn_data)
    + aes(x = "gender", fill = "Churn")
    + geom_bar(position = "dodge")
)

# %% [markdown]
# No Distinctive pattern found on number of churn between genders. It shows the same pattern for both class

# %%
churn_data["SeniorCitizen"].value_counts(sort = True)
#Convert SeniorCitizen Column into categorical column
churn_data["SeniorCitizen"] = churn_data["SeniorCitizen"].astype('category')

# %%
churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   category
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
(
    ggplot(churn_data) +
    aes(x = "SeniorCitizen", fill = "Churn") +
    geom_bar(position = "dodge")
)

# %%
churn_data["Partner"].value_counts(sort = True)
# Out:
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %%
(
    ggplot(churn_data) +
    aes(x = "Partner", fill = "Churn") +
    geom_bar(position = "dodge")
)

# %% [markdown]
# Same pattern shows on Churn for both Partner class

# %%
churn_data["Dependents"].value_counts(sort = True)
# Out:
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64

# %%
(
    ggplot(churn_data) +
    aes(x = "Dependents", fill = "Churn") +
    geom_bar(position = "dodge")
)

# %% [markdown]
# We have less Churn count on customers with Dependents. Even though both class of Dependents shows the same pattern for Churn

# %%
(
    ggplot(churn_data) +
    aes(x = "tenure", fill = "Churn") +
    geom_histogram()
)
# Out:
# c:\Users\rayjohndp\Desktop\Projects\DS_Python_Portfolio\Telecom_Churn_Project\ML_Churn_Pred\Lib\site-packages\plotnine\stats\stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 16'. Pick better value with 'binwidth'.

# %%
#Create function for plotting geom bar plot

def gg_barplot(data = churn_data,x = ""):
    plotresult = (
        ggplot(data) +
        aes(x = x, fill = "Churn") +
        geom_bar(position = "dodge") +
        coord_flip()
    )

    return plotresult

# %%
gg_barplot(churn_data,x = "PhoneService")

# %% [markdown]
# There are more customers that has a phone service. Pattern for both class in terms of Churn count is the same

# %%
gg_barplot(x = "MultipleLines")

# %% [markdown]
# We have more customers that did not churn than customers that did churn on all class of Multiple Lines

# %%
gg_barplot(x = "InternetService")

# %% [markdown]
# Even though the pattern seems to be the same on all classes, we can see that on Fiber Optic, there is a lot churners recorded.

# %%
gg_barplot(x = "OnlineSecurity")

# %% [markdown]
# We have more churns on Customers that do not have OnlineSecurity on their subscription

# %%
gg_barplot(x = "OnlineBackup")

# %% [markdown]
# Almost the same pattern with Online Security, maybe these 2 columns comes in a bundle?

# %%
gg_barplot(x = "DeviceProtection")

# %%
gg_barplot(x = "TechSupport")

# %%
gg_barplot(x = "StreamingTV")

# %%
gg_barplot(x = "StreamingMovies")

# %%
gg_barplot(x = "Contract")

# %% [markdown]
# We have more churners on our month-to-month contract

# %%
gg_barplot(x = "PaperlessBilling")

# %%
gg_barplot(x = "PaymentMethod")

# %% [markdown]
# Most of our churners came from customers that has an Electronic Check for Billing method.

# %%
(
    ggplot(churn_data) +
    aes(x = "MonthlyCharges", fill = "Churn") +
    geom_histogram()
)
# Out:
# c:\Users\rayjohndp\Desktop\Projects\DS_Python_Portfolio\Telecom_Churn_Project\ML_Churn_Pred\Lib\site-packages\plotnine\stats\stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 18'. Pick better value with 'binwidth'.

# %%
churn_data["TotalCharges"].value_counts(sort=True)
# Out:
# TotalCharges
#           11
# 20.2      11
# 19.75      9
# 20.05      8
# 19.9       8
#           ..
# 6849.4     1
# 692.35     1
# 130.15     1
# 3211.9     1
# 6844.5     1
# Name: count, Length: 6531, dtype: int64

# %%
churn_data["TotalCharges"] = np.where(churn_data["TotalCharges"] == " ","0",churn_data["TotalCharges"])
churn_data["TotalCharges"] = churn_data["TotalCharges"].astype("float")

# %%
(
    ggplot(churn_data) +
    aes(x = "TotalCharges", fill = "Churn") +
    geom_histogram()
)
# Out:
# c:\Users\rayjohndp\Desktop\Projects\DS_Python_Portfolio\Telecom_Churn_Project\ML_Churn_Pred\Lib\site-packages\plotnine\stats\stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 25'. Pick better value with 'binwidth'.

# %%
churn_data[["numAdminTickets","numTechTickets"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   numAdminTickets  7043 non-null   int64
#  1   numTechTickets   7043 non-null   int64
# dtypes: int64(2)
# memory usage: 110.2 KB

# %%
gg_barplot(x = "numAdminTickets")

# %%
gg_barplot(x = "numTechTickets")

# %%
churn_data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# numAdminTickets     0
# numTechTickets      0
# Churn               0
# dtype: int64
